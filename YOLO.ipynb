# %%
import torch
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /home/tajasvi/.cache/torch/hub/ultralytics_yolov5_master
# fatal: not a git repository (or any of the parent directories): .git
# YOLOv5 🚀 2022-4-13 torch 1.8.2+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# Adding AutoShape...

# %%
img = 'https://thumbs.dreamstime.com/z/loving-tender-moment-men-horse-young-man-smiling-174963966.jpg'

# %%
result = model(img)

# %%
result.print()
# Out:
# image 1/1: 1155x1600 1 person, 1 horse
# Speed: 755.1ms pre-process, 161.0ms inference, 0.9ms NMS per image at shape (1, 3, 480, 640)

# %%
np.array(result.render()).shape
# Out:
# (1, 1155, 1600, 3)

# %%
plt.imshow(np.squeeze(result.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)

while True:
    img , frame = cap.read()
    
    result = model(frame)
    
    cv2.imshow('Frame',np.squeeze(result.render()))
    
    k = cv2.waitKey(1)
    if k == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x55d48359ab00) is not the object's thread (0x55d483213d80).
# Cannot move to target thread (0x55d48359ab00)
#
# QObject::moveToThread: Current thread (0x55d48359ab00) is not the object's thread (0x55d483213d80).
# Cannot move to target thread (0x55d48359ab00)
#
# QObject::moveToThread: Current thread (0x55d48359ab00) is not the object's thread (0x55d483213d80).
# Cannot move to target thread (0x55d48359ab00)
#
# QObject::moveToThread: Current thread (0x55d48359ab00) is not the object's thread (0x55d483213d80).
# Cannot move to target thread (0x55d48359ab00)
#
# QObject::moveToThread: Current thread (0x55d48359ab00) is not the object's thread (0x55d483213d80).
# Cannot move to target thread (0x55d48359ab00)
#
# QObject::moveToThread: Current thread (0x55d48359ab00) is not the object's thread (0x55d483213d80).
# Cannot move to target thread (0x55d48359ab00)
#
# ...

# %%
import uuid
import time
import os

# %%
pwd
# Out:
# '/home/tajasvi/Documents/Teja/yolov5'

# %%
Images_path = os.path.join('data','images')

labels = ['Awake' , 'Drowsy']

num_imgs = 20

# %%
#For collecting Images from webcam

cap = cv2.VideoCapture(0)

for label in labels:
    print("Collecting Images for {} :".format(label))
    time.sleep(5)
    
    for img_num in range(num_imgs):
        print("Collecting Images for {}, image number{} :".format(label,img_num))
        
        ret , frame = cap.read()
        
        imgname = os.path.join(Images_path, label+','+str(uuid.uuid1())+'.jpg')
        
        cv2.imwrite(imgname,frame)
        
        cv2.imshow('Image Collection', frame)
        time.sleep(2)
        
        k = cv2.waitKey(1)
        if k == ord('q'):
            break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# QObject::moveToThread: Current thread (0x56440ba607e0) is not the object's thread (0x56440d8b43f0).
# Cannot move to target thread (0x56440ba607e0)
#
# QObject::moveToThread: Current thread (0x56440ba607e0) is not the object's thread (0x56440d8b43f0).
# Cannot move to target thread (0x56440ba607e0)
#
# QObject::moveToThread: Current thread (0x56440ba607e0) is not the object's thread (0x56440d8b43f0).
# Cannot move to target thread (0x56440ba607e0)
#
# QObject::moveToThread: Current thread (0x56440ba607e0) is not the object's thread (0x56440d8b43f0).
# Cannot move to target thread (0x56440ba607e0)
#
# QObject::moveToThread: Current thread (0x56440ba607e0) is not the object's thread (0x56440d8b43f0).
# Cannot move to target thread (0x56440ba607e0)
#
# QObject::moveToThread: Current thread (0x56440ba607e0) is not the object's thread (0x56440d8b43f0).
# Cannot move to target thread (0x56440ba607e0)
#
# ...

# %%
# !git clone https://github.com/tzutalin/labelImg.git
# Out:
# Cloning into 'labelImg'...
# remote: Enumerating objects: 1978, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1978 (delta 0), reused 0 (delta 0), pack-reused 1977
# Receiving objects: 100% (1978/1978), 232.83 MiB | 3.86 MiB/s, done.
# Resolving deltas: 100% (1182/1182), done.

# %%
# !pip install pyqt5 lxml --upgrade

# %%
pwd
# Out:
# '/home/tajasvi/Documents/Teja/yolov5'

# %%
# !python train.py --img 320 --batch 16 --epochs 500 --data /home/tajasvi/Documents/Teja/yolov5/dataset.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=/home/tajasvi/Documents/Teja/yolov5/dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-129-g74aaab3 torch 1.8.2+cpu CPU
#
# ...

# %%
model = torch.hub.load('ultralytics/yolov5','custom', path='runs/train/exp15/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /home/tajasvi/.cache/torch/hub/master.zip
# fatal: not a git repository (or any of the parent directories): .git
# YOLOv5 🚀 2022-4-13 torch 1.8.2+cpu CPU
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
images = os.path.join('data','images','drowsy,fcc57e7c-ba44-11ec-9143-b5888042bdfd.jpg')

# %%
print(images)
# Out:
# data/images/drowsy,fcc57e7c-ba44-11ec-9143-b5888042bdfd.jpg

# %%
len(images)
# Out:
# 59

# %%
result = model(images)

# %%
result.print()
# Out:
# image 1/1: 480x640 1 person
# Speed: 20.2ms pre-process, 144.5ms inference, 0.7ms NMS per image at shape (1, 3, 480, 640)

# %%
plt.imshow(np.squeeze(result.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)

while True:
    img , frame = cap.read()
    
    result = model(frame)
    
    cv2.imshow('Frame',np.squeeze(result.render()))
    
    k = cv2.waitKey(1)
    if k == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x56440ba607e0) is not the object's thread (0x56440d8b43f0).
# Cannot move to target thread (0x56440ba607e0)
#
# QObject::moveToThread: Current thread (0x56440ba607e0) is not the object's thread (0x56440d8b43f0).
# Cannot move to target thread (0x56440ba607e0)
#
# QObject::moveToThread: Current thread (0x56440ba607e0) is not the object's thread (0x56440d8b43f0).
# Cannot move to target thread (0x56440ba607e0)
#
# QObject::moveToThread: Current thread (0x56440ba607e0) is not the object's thread (0x56440d8b43f0).
# Cannot move to target thread (0x56440ba607e0)
#
# QObject::moveToThread: Current thread (0x56440ba607e0) is not the object's thread (0x56440d8b43f0).
# Cannot move to target thread (0x56440ba607e0)
#
# QObject::moveToThread: Current thread (0x56440ba607e0) is not the object's thread (0x56440d8b43f0).
# Cannot move to target thread (0x56440ba607e0)
#
# ...
